# %%
# !pip install apify-client
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\62895\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_4fpqVbekBRKZ0RZiHJX---------------")

# Prepare the Actor input
run_input = {
    "commentsPerPost": 1000,
    "excludePinnedPosts": False,
    "maxRepliesPerComment": 4,
    "postURLs": [
        "https://www.tiktok.com/@bank_indonesia/video/7517103704307272968"
    ],
    "resultsPerPage": 100
}

# Run the Actor and wait for it to finish
run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)

items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
# Out:
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> 2025-08-20T04:39:28.770Z ACTOR: Pulling Docker image of build zIhZ6zPJcWhS6wkai from registry.
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> 2025-08-20T04:39:34.136Z ACTOR: Creating Docker container.
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> 2025-08-20T04:39:36.007Z ACTOR: Starting Docker container.
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> 2025-08-20T04:39:36.485Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:9Ee8Wz4sahXbv9z4d] -> 2025-08-20T04:39:37.818Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.4"}
# ...

# %%
import pandas as pd

df = pd.DataFrame(items)
df
# Out:
#                                            videoWebUrl  \
# 0    https://www.tiktok.com/@bank_indonesia/video/7...
# 1    https://www.tiktok.com/@bank_indonesia/video/7...
# 2    https://www.tiktok.com/@bank_indonesia/video/7...
# 3    https://www.tiktok.com/@bank_indonesia/video/7...
# 4    https://www.tiktok.com/@bank_indonesia/video/7...
# ..                                                 ...
# 995  https://www.tiktok.com/@bank_indonesia/video/7...
# 996  https://www.tiktok.com/@bank_indonesia/video/7...
# 997  https://www.tiktok.com/@bank_indonesia/video/7...
# 998  https://www.tiktok.com/@bank_indonesia/video/7...
# 999  https://www.tiktok.com/@bank_indonesia/video/7...
#
#                                      submittedVideoUrl  \
# 0    https://www.tiktok.com/@bank_indonesia/video/7...
# 1    https://www.tiktok.com/@bank_indonesia/video/7...
# 2    https://www.tiktok.com/@bank_indonesia/video/7...
# 3    https://www.tiktok.com/@bank_indonesia/video/7...
# ...

# %%
df.to_excel('dataset.xlsx', index=False)
